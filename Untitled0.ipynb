# %%
D=dict(name='BOB',
      age=25,
       job='Dev')
print(D)
# Out:
# {'name': 'BOB', 'age': 25, 'job': 'Dev'}

# %%
T=(['john','tommy'],
   [35,57])
d=dict(T)
print(d)
# Out:
# {'john': 'tommy', 35: 57}

# %%
L=[('Sonny',36),
   ('Virat',73)]
d=dict(L)
print(d)
# Out:
# {'Sonny': 36, 'Virat': 73}

# %%
keys=['Name','age','job']
values=['John',36,'developer']
