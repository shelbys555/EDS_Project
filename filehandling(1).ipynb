# %%
f=open("file1","a")
f.write("Read the first 50 characters")
f.close()

f=open("file1","r")
print(f.read(20))
print(f.readline())
f.close
# Out:
# Now the file has mor
# e content!Now the file has more content!Read the first 50 charactersRead the first 50 charactersRead the first 50 characters
# <function TextIOWrapper.close()>
