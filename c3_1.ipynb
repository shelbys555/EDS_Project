# %%
list1 = [35,67,97.6,'Thomas','John']
list2 = [7,8,9]
list3 = ['BMW','Mercedes','Porsche']
list1.append('Arthur')
print(list1)


list1.extend(list3)
print(list1)

list2.insert(2,10)
print(list2)

list3.remove('BMW')
list3.insert(0,'Bentley')
print(list3)

list1.pop(-2)
print(list1)

print(list1[::-1])

print(len(list1))
print(len(list2))
print(len(list3))

print(min(list2))
print(max(list3))

print(list2.count(10))

print(list1 + list2)

#print(list1*2)

print(list1.index('Arthur'))
print(list1)
# Out:
# [35, 67, 97.6, 'Thomas', 'John', 'Arthur']
# [35, 67, 97.6, 'Thomas', 'John', 'Arthur', 'BMW', 'Mercedes', 'Porsche']
# [7, 8, 10, 9]
# ['Bentley', 'Mercedes', 'Porsche']
# [35, 67, 97.6, 'Thomas', 'John', 'Arthur', 'BMW', 'Porsche']
# ['Porsche', 'BMW', 'Arthur', 'John', 'Thomas', 97.6, 67, 35]
# 8
# 4
# 3
# 7
# Porsche
# 1
# [35, 67, 97.6, 'Thomas', 'John', 'Arthur', 'BMW', 'Porsche', 7, 8, 10, 9]
# 5
# [35, 67, 97.6, 'Thomas', 'John', 'Arthur', 'BMW', 'Porsche']
